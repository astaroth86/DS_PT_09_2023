# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("../data/raw/coches.csv")

# %%
df.head()
# Out:
#                                 url                           company  \
# 0  e158ae0ca53119ca199c28c36b5c2fcd  9881bcdd5a0ad4733037b3fb25e69c3a
# 1  ff267ebb7e700246f47f84f3db660b4b  9881bcdd5a0ad4733037b3fb25e69c3a
# 2  de4b02db28ea7786c622b969be10c7c7  9881bcdd5a0ad4733037b3fb25e69c3a
# 3  0449972a4d07594acf92e9a7dd28b39c  9881bcdd5a0ad4733037b3fb25e69c3a
# 4  12c4fa49bd4fdf23f19ecf396d3f02ef  9881bcdd5a0ad4733037b3fb25e69c3a
#
#          make            model  \
# 0        SEAT           Toledo
# 1     CITROEN               C1
# 2        FORD  Transit Connect
# 3  VOLKSWAGEN        Caravelle
# 4        FORD          Transit
#
#                                              version  price  price_financed  \
# 0                                   SEAT Toledo  4p.    950             NaN
# 1             CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200             NaN
# 2  FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851          7024.0
# 3  VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426             NaN
# 4  FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850         22800.0
#
#        fuel    year     kms  ...  doors   shift   color photos  \
# 0    Diésel  2000.0  227000  ...      4  Manual   Verde      5
# 1  Gasolina  2017.0   50071  ...      5  Manual  Blanco      6
# 2    Diésel  2016.0  103000  ...      4  Manual  Blanco     10
# 3    Diésel  2014.0  120000  ...      4  Manual  Blanco      9
# 4    Diésel  2017.0  107000  ...      2  Manual  Blanco      4
#
#    is_professional                            dealer   province country  \
# 0            False  0f4bb8455d27349b8273109b66a847f3    Navarra   Spain
# 1             True                     Autos Raymara   Tenerife   Spain
# 2             True                           Auto 96  Barcelona   Spain
# 3             True                          Inniauto    Navarra   Spain
# 4             True              Autofleet España,s.l    Sevilla   Spain
#
#           publish_date          insert_date
# 0  2020-12-18 10:47:13  2021-01-15 00:00:00
# 1  2021-01-02 11:25:40  2021-01-15 00:00:00
# 2  2020-12-16 10:51:45  2021-01-15 00:00:00
# 3  2020-11-25 11:09:14  2021-01-15 00:00:00
# 4  2021-01-12 20:00:34  2021-01-15 00:00:00
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#                                     url                           company  \
# 49995  730210734bfbe1d3df878d5df71246f2  9881bcdd5a0ad4733037b3fb25e69c3a
# 49996  732b04fb47dd9559dbdcd099c5af484e  9881bcdd5a0ad4733037b3fb25e69c3a
# 49997  c10afb53957fb8012707239bdfa66018  9881bcdd5a0ad4733037b3fb25e69c3a
# 49998  f74363a6688ba11b71b4d980a959b8d3  9881bcdd5a0ad4733037b3fb25e69c3a
# 49999  3d60801ccb96ef038747130e8a34ceda  9881bcdd5a0ad4733037b3fb25e69c3a
#
#           make   model                                            version  \
# 49995  HYUNDAI     i30        HYUNDAI i30 1.4 TGDI Tecno Fastback DCT 5p.
# 49996  RENAULT  Laguna  RENAULT Laguna Coupe Limited 2.0 Energy dCi 15...
# 49997  PEUGEOT     108           PEUGEOT 108 TOP Allure VTi 52kW 72CV 5p.
# 49998     AUDI     RS4           AUDI RS4 Avant 4.2 FSI 450cv quattro 5p.
# 49999  CITROEN      C2                    CITROEN C2 1.4 HDI VTR Plus 3p.
#
#        price  price_financed      fuel    year     kms  ...  doors  \
# 49995  18490         16490.0  Gasolina  2018.0   47000  ...      5
# 49996  14500         13551.0    Diésel  2015.0   68750  ...      2
# 49997  11000          9000.0  Gasolina  2019.0   21422  ...      5
# 49998  47900             NaN  Gasolina  2013.0   47900  ...      5
# 49999   2790             NaN    Diésel  2006.0  106000  ...      3
#
#             shift                           color photos  is_professional  \
# 49995  Automático                    Gris / Plata     26             True
# 49996      Manual  KNG Gris Casiopea (metalizado)     30             True
# 49997      Manual                    Gris / Plata     17             True
# 49998  Automático        Gris / Plata (Antracita)     20             True
# 49999      Manual                           Negro     21             True
#
#                   dealer   province country         publish_date  \
# 49995    Flexicar Málaga     Málaga   Spain  2020-11-24 19:59:52
# 49996       Ocasion Plus     Málaga   Spain  2021-01-13 17:02:41
# 49997  Psa Retail Huelva     Huelva   Spain  2021-01-08 16:47:24
# 49998     Codigocar Lugo       Lugo   Spain  2021-01-13 16:22:53
# 49999    AUTOVALENCIA 19  Barcelona   Spain  2021-01-10 16:32:41
#
#                insert_date
# 49995  2021-01-15 00:00:00
# 49996  2021-01-15 00:00:00
# 49997  2021-01-15 00:00:00
# 49998  2021-01-15 00:00:00
# 49999  2021-01-15 00:00:00
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              50000 non-null  object
#  1   company          50000 non-null  object
#  2   make             49998 non-null  object
#  3   model            49995 non-null  object
#  4   version          50000 non-null  object
#  5   price            50000 non-null  int64
#  6   price_financed   23563 non-null  float64
#  7   fuel             49954 non-null  object
#  8   year             49998 non-null  float64
#  9   kms              50000 non-null  int64
#  10  power            41472 non-null  float64
#  11  doors            50000 non-null  int64
#  12  shift            49889 non-null  object
#  13  color            49406 non-null  object
#  14  photos           50000 non-null  int64
#  15  is_professional  50000 non-null  bool
#  16  dealer           50000 non-null  object
#  17  province         49994 non-null  object
#  18  country          50000 non-null  object
#  19  publish_date     50000 non-null  object
#  20  insert_date      50000 non-null  object
# dtypes: bool(1), float64(3), int64(4), object(13)
# memory usage: 7.7+ MB

# %%
df.describe()
# Out:
#                price  price_financed          year           kms  \
# count   50000.000000    23563.000000  49998.000000  5.000000e+04
# mean    15166.270260    18480.029283   2012.311032  1.163591e+05
# std     16485.669747    13389.800738      6.677760  1.072921e+05
# min       300.000000      700.000000   1970.000000  0.000000e+00
# 25%      5500.000000    10790.000000   2007.000000  3.830000e+04
# 50%     11750.000000    15500.000000   2015.000000  9.999900e+04
# 75%     19800.000000    21995.000000   2018.000000  1.749000e+05
# max    549900.000000   428999.000000   2021.000000  5.000000e+06
#
#               power         doors        photos
# count  41472.000000  50000.000000  50000.000000
# mean     146.396388      4.505380     16.199120
# std       71.283964      0.868001     12.422882
# min       29.000000      2.000000      0.000000
# 25%      109.000000      4.000000      7.000000
# 50%      130.000000      5.000000     13.000000
# 75%      163.000000      5.000000     23.000000
# max      800.000000      5.000000     54.000000

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [url, company, make, model, version, price, price_financed, fuel, year, kms, power, doors, shift, color, photos, is_professional, dealer, province, country, publish_date, insert_date]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# url                    0
# company                0
# make                   2
# model                  5
# version                0
# price                  0
# price_financed     26437
# fuel                  46
# year                   2
# kms                    0
# power               8528
# doors                  0
# shift                111
# color                594
# photos                 0
# is_professional        0
# dealer                 0
# province               6
# country                0
# publish_date           0
# insert_date            0
# dtype: int64

# %%
df[df['make'] == 'DAEWOO']
# Out:
#                                     url                           company  \
# 1831   c6eeeb069f83f79b1dc88d8f5187340e  9881bcdd5a0ad4733037b3fb25e69c3a
# 2618   1aa5167683e1ff58cb935ecbb557c610  9881bcdd5a0ad4733037b3fb25e69c3a
# 3462   194ef979012ec14fcef964e3af00b416  9881bcdd5a0ad4733037b3fb25e69c3a
# 4225   2a83bb84e7d34beae54169dda2e5aca2  9881bcdd5a0ad4733037b3fb25e69c3a
# 4609   d3241e9a606152cf06261df2386a184f  9881bcdd5a0ad4733037b3fb25e69c3a
# 4881   87951ba5b1bfce32b3769b0bb7a1b62f  9881bcdd5a0ad4733037b3fb25e69c3a
# 9336   e714f7a547faf37965f6e0e83e1f8232  9881bcdd5a0ad4733037b3fb25e69c3a
# 11154  8ae7396055a2ff9fdacd65f5e7d38ae9  9881bcdd5a0ad4733037b3fb25e69c3a
# 11210  9f3dce3a5e413dba036812928832cdac  9881bcdd5a0ad4733037b3fb25e69c3a
# 12248  b094ff8ba65cea35251577732ef8c1b4  9881bcdd5a0ad4733037b3fb25e69c3a
# 13350  fd49e0d0c171acb326d2223974c68c8b  9881bcdd5a0ad4733037b3fb25e69c3a
# 13781  60079fa85dd1a45217009a9bcd5e1522  9881bcdd5a0ad4733037b3fb25e69c3a
# 14349  6ab3e163a24175f3dd1ea7f0d76c716f  9881bcdd5a0ad4733037b3fb25e69c3a
# 14910  f00731649c9feeaee116183304a03459  9881bcdd5a0ad4733037b3fb25e69c3a
# 16621  19db9ba60176a2a10aa3171d6e276b01  9881bcdd5a0ad4733037b3fb25e69c3a
# 16624  284e75035bf0cb5161c783716765107e  9881bcdd5a0ad4733037b3fb25e69c3a
# 17560  fd5fd954494d69a15bb6947965934e88  9881bcdd5a0ad4733037b3fb25e69c3a
# 18741  cff191b86fab05d79de77caf832cd7e4  9881bcdd5a0ad4733037b3fb25e69c3a
# 18960  f460e549e564dd45de49a02bffde1517  9881bcdd5a0ad4733037b3fb25e69c3a
# 19850  bf68b8a0444c55b1f83400a275a70ada  9881bcdd5a0ad4733037b3fb25e69c3a
# 20558  202eb155b9491bf4b4eed883f7075a34  9881bcdd5a0ad4733037b3fb25e69c3a
# 22940  20af0cfe70126acdd404e2b1595c6674  9881bcdd5a0ad4733037b3fb25e69c3a
# 23089  9359e89a91192731dae89c97a16e3ac4  9881bcdd5a0ad4733037b3fb25e69c3a
# 24479  943261e0dff48862b16ea77e8ae55b5d  9881bcdd5a0ad4733037b3fb25e69c3a
# 24994  ef9243eafe3ddae33c4728753a3d3030  9881bcdd5a0ad4733037b3fb25e69c3a
# 25896  0638bf59ed46b4f11efb020072f196a1  9881bcdd5a0ad4733037b3fb25e69c3a
# 25928  a922d40465f5c11c07afd4c1418a8711  9881bcdd5a0ad4733037b3fb25e69c3a
# 27238  42227efcf327cf5d7f2175047fbbe3ba  9881bcdd5a0ad4733037b3fb25e69c3a
# 27571  ce154584c5c814f81727da354791702f  9881bcdd5a0ad4733037b3fb25e69c3a
# 31204  ee5e4cbfdc1da86bc6f733675f2540b6  9881bcdd5a0ad4733037b3fb25e69c3a
# 32201  b415310495ee5bdfda0dcbf799b2b8d4  9881bcdd5a0ad4733037b3fb25e69c3a
# 32227  76a06bd31c49a9799e2e714b53603e26  9881bcdd5a0ad4733037b3fb25e69c3a
# 33490  5a2b27d6bbf137c619043456deff2931  9881bcdd5a0ad4733037b3fb25e69c3a
# 35511  681361fedd477eb611775c9b3337db20  9881bcdd5a0ad4733037b3fb25e69c3a
# 36358  c2846df338df46efd4481fd2499bfaf5  9881bcdd5a0ad4733037b3fb25e69c3a
# 38162  afa3e707e06213bf3ae957a076b6e28a  9881bcdd5a0ad4733037b3fb25e69c3a
# 38700  00a24b7fc91130b5b839dd35869c253c  9881bcdd5a0ad4733037b3fb25e69c3a
# 38933  806133dfce7b363e64e526cff080e1c2  9881bcdd5a0ad4733037b3fb25e69c3a
# 39979  a7f8dd6f08d0558a6e06c2b8d6c63faa  9881bcdd5a0ad4733037b3fb25e69c3a
# 40207  111146024aa09c585337a67681dee95e  9881bcdd5a0ad4733037b3fb25e69c3a
# 45439  3ec47ff3b0ef993ac36fcb251c0a77e5  9881bcdd5a0ad4733037b3fb25e69c3a
# 46023  556f2fdee2cd3b2c4b2ab35b34aec17b  9881bcdd5a0ad4733037b3fb25e69c3a
# 46089  75c6be281907b2df5f4f1c056a552a35  9881bcdd5a0ad4733037b3fb25e69c3a
# 46762  096564a1317749f2b424550857e99503  9881bcdd5a0ad4733037b3fb25e69c3a
# 49290  6fbfe35e37cee6bbd70b9c18ca904fbf  9881bcdd5a0ad4733037b3fb25e69c3a
#
#          make    model                                         version  price  \
# 1831   DAEWOO   Nubira                DAEWOO Nubira CLASSIC 1.6 SE 5p.    690
# 2618   DAEWOO   Nubira                        DAEWOO Nubira 1.6 SX 5p.   2490
# 3462   DAEWOO    Matiz                             DAEWOO Matiz CD 5p.   1000
# 4225   DAEWOO    Lanos                                          DAEWOO   1000
# 4609   DAEWOO    Lanos                         DAEWOO Lanos 1.5 SE 3p.    695
# 4881   DAEWOO   Evanda                       DAEWOO Evanda 2.0 CDX 4p.   1999
# 9336   DAEWOO   Nubira        DAEWOO Nubira 1.6 SX ano modelo 2004 4p.   1700
# 11154  DAEWOO    Matiz                         DAEWOO Matiz 1.0 CD 5p.   1999
# 11210  DAEWOO    Lanos                               DAEWOO Lanos  3p.   1300
# 12248  DAEWOO    Matiz                             DAEWOO Matiz SE 5p.   2500
# 13350  DAEWOO    Kalos                     DAEWOO Kalos 1.4 SR 16v 4p.   1700
# 13781  DAEWOO   Evanda  DAEWOO Evanda 2.0 CDX AUTO ano modelo 2004 4p.   2500
# 14349  DAEWOO  Leganza                      DAEWOO Leganza 2.0 CDX 4p.   1300
# 14910  DAEWOO   Nubira                              DAEWOO Nubira  5p.    600
# 16621  DAEWOO    Lanos                    DAEWOO Lanos 1.6 SX Plus 3p.    800
# 14349             NaN  Gasolina  2001.0  140000  ...      4      Manual
# 14910             NaN  Gasolina  1999.0  178128  ...      5      Manual
# 16621             NaN  Gasolina  2001.0   99000  ...      3      Manual
# 16624             NaN    Diésel  2005.0   76000  ...      5      Manual
# 17560             NaN  Gasolina  2003.0  250000  ...      4      Manual
# 18741             NaN  Gasolina  2001.0   95000  ...      5      Manual
# 18960             NaN  Gasolina  2002.0  155400  ...      5      Manual
# 19850             NaN  Gasolina  2002.0   86388  ...      5      Manual
# 20558             NaN  Gasolina  2002.0   51000  ...      5      Manual
# 22940             NaN  Gasolina  2003.0  136000  ...      5      Manual
# 23089             NaN  Gasolina  1997.0   98000  ...      5      Manual
# 24479             NaN  Gasolina  2000.0  120000  ...      5      Manual
# 24994             NaN  Gasolina  2002.0  125078  ...      5      Manual
# 25896             NaN  Gasolina  2004.0  180000  ...      5      Manual
# 25928             NaN  Gasolina  2000.0  147000  ...      5      Manual
# 27238             NaN  Gasolina  2004.0  114000  ...      4      Manual
# 27571             NaN  Gasolina  2000.0  140000  ...      5      Manual
# 31204             NaN  Gasolina  2000.0   65000  ...      5      Manual
# 32201             NaN  Gasolina  2000.0   91000  ...      3      Manual
# 32227             NaN  Gasolina  2004.0   92000  ...      4  Automático
# 33490             NaN  Gasolina  2004.0  138000  ...      5      Manual
# 35511             NaN  Gasolina  2005.0  127000  ...      5      Manual
# 36358             NaN  Gasolina  2003.0  130000  ...      5      Manual
# 38162             NaN  Gasolina  1997.0  180000  ...      5      Manual
# 38700             NaN  Gasolina  2000.0  132300  ...      5      Manual
# 38933             NaN  Gasolina  2004.0   67000  ...      5      Manual
# 39979             NaN  Gasolina  1998.0  175000  ...      5      Manual
# 40207             NaN  Gasolina  2005.0   99000  ...      5      Manual
# 45439             NaN  Gasolina  2001.0  150082  ...      5      Manual
# 46023             NaN  Gasolina  2003.0  250000  ...      4      Manual
# 46089             NaN  Gasolina  2004.0   94339  ...      4         NaN
# 46762             NaN  Gasolina  2001.0  185000  ...      5      Manual
# 49290          1999.0  Gasolina  2001.0   90000  ...      5      Manual
#
#                     color photos  is_professional  \
# 1831                 Azul     27            False
# 2618                Verde     10             True
# 3462         Gris / Plata      6            False
# 4225                 Rojo      5            False
# 4609         Gris / Plata      3            False
# 4881                Beige     12             True
# 9336                Verde     23            False
# 11154               Verde      9             True
# 11210                Rojo      3            False
# 12248        Gris / Plata     54             True
# 13350  Azul (MUY CUIDADO)     14             True
# 13781                Azul     18             True
# 14349               Verde      1            False
# 14910        Gris / Plata      6            False
# 16621               Negro      5            False
# 16624        Gris / Plata      8            False
# 17560               Beige     10            False
# 18741                Azul      6            False
# 18960               Verde      9            False
# 19850               Verde      8            False
# 20558               Verde      0            False
# 22940                Azul      0            False
# 23089        Gris / Plata      8            False
# 24479              Blanco      4            False
# 24994                Rojo      7            False
# 25896              Blanco      4            False
# 25928        Gris / Plata      8            False
# 27238                Azul     11             True
# 27571               Negro      9            False
# 31204        Gris / Plata      4            False
# 32201                Azul      9            False
# 32227        Gris / Plata      9             True
# 33490        Gris / Plata      5            False
# 35511                Azul      4            False
# 36358                Azul      2            False
# 38162              Blanco      6            False
# 38700                Azul     12            False
# 38933        Gris / Plata      0            False
# 39979                Azul      0            False
# 40207                Azul      1            False
# 45439        Gris / Plata      6            False
# 46023            Amarillo      0            False
# 46089        Gris / Plata      9            False
# 46762        Gris / Plata      2            False
# 49290        Gris / Plata      5             True
#
#                                  dealer   province country  \
# 1831   a660439bf2096c599c766209160f5bbc     Madrid   Spain
# 2618       AUTOMOVILES NOU OCASION FRAN   Valencia   Spain
# 3462   67a2a324cb08c0b2f02d096eceee933b    Almería   Spain
# 4225   92a1c9ccfe96b3d9a1398a5de818282e    Sevilla   Spain
# 4609   ab02fceb9689114b1cd1844e456c0695     Málaga   Spain
# 4881                           JCars.es   Valencia   Spain
# 9336   464e07afc9e46359fb480839150595c5     Madrid   Spain
# 11154                      Autos&Camper   Zaragoza   Spain
# 11210  0a727460658d6897c9e9d0fcdbce53f3   Valencia   Spain
# 12248                   Automoción Pere  Tarragona   Spain
# 13350                    Autos Illescar     Madrid   Spain
# 13781                        Safor Auto   Valencia   Spain
# 14349  cd20d1123ee9016d84fe79e49fa30a9f     Madrid   Spain
# 14910  b3cbfd5b4cf1646970f7392b78ec0379   Alicante   Spain
# 16621  0b5f2368b0009b34441ee101e309ada6  Tarragona   Spain
# 16624  c44688b5061756b3cca2b86c016a1535     Málaga   Spain
# 17560  1a3982ea0fc8f9a9cd5dc9cfef4f0f93   Tenerife   Spain
# 18741  f7e2c8f9fe8e1da0b4f169f49d2136dd    Córdoba   Spain
# 18960  24f7ab257e4e414dc5aa0dcce7068b3e  Barcelona   Spain
# 19850  4f334343cb39942ad197f18cace9668a   Valencia   Spain
# 20558  19d3d0afc6d987bb0099105e561338a6      Álava   Spain
# 22940  f866e632ae10d6db3aac7cb9bed2002e   Alicante   Spain
# 23089  98db6b79acb71383b5a83e0bbc1cadd4     Madrid   Spain
# 24479  85304a3e775b5ab9f7caf784a3fdc4b0    Granada   Spain
# 24994  c7ec7622a90bff8a4f08ba7f4a3dd490   Valencia   Spain
# 25896  3d955b296b014a077facdc24e8dbaf89  Tarragona   Spain
# 25928  8fe918632d847e8ea3ebffbd47bd8ca9     Málaga   Spain
# 27238                         Roberauto     Madrid   Spain
# 27571  70483b6e100c9cebbffcdc62dea07eda    Granada   Spain
# 31204  b70e2a0d855b4dc7b1ea34a8a9d10305   Valencia   Spain
# 32201  e4b4a516353108a1b8673eaddd60f63d  Barcelona   Spain
# 32227                MARTIN AVILA MOTOR     Madrid   Spain
# 33490  f4a1c8901a3d406f17af67144a3ec71a       León   Spain
# 35511  3ff8324c1d89c3091218607216944be5     Madrid   Spain
# 36358  abf3ff33a13d439824361e15d4a518bb   Asturias   Spain
# 38162  066fc7b468bbf62055fe69a4f097de90     Madrid   Spain
# 38700  5f57473d2f29db7bbe1ea5fb4c95ea02     Toledo   Spain
# 38933  885383f16fccd10370814fcd862aa10d      Cádiz   Spain
# 39979  63e2c694cdef855adbcb71a4c7c30db8    Sevilla   Spain
# 40207  2ee583674ac854c934f7a6d55f3d1c2e   Valencia   Spain
# 45439  4983ce5db00ae6b61874c3a3c8dbc176      Cádiz   Spain
# %%
len(df['model'].unique())
# Out:
# 941

# %%
len(df['version'].unique())
# Out:
# 17397

# %%
df['fuel'].unique()
# Out:
# array(['Gasolina', 'Diésel', 'Híbrido enchufable', 'Eléctrico',
#        'Gas natural (CNG)', 'Híbrido', 'Gas licuado (GLP)'], dtype=object)

# %%
df['shift'].unique()
# Out:
# array(['Manual', 'Automático'], dtype=object)

# %%
df['color'].unique()
# Out:
# array(['Blanco', 'Azul', 'Gris / Plata', ..., 'Gris Urano (sólido)',
#        'Blanco (ICE WHITE SOLID)',
#        'Azul (OFERTA MES!!! ENTREGA INMEDIATA!!!)'], dtype=object)

# %%
df['province'].unique()
# Out:
# array(['Tenerife', 'Barcelona', 'Navarra', 'Sevilla', 'Madrid',
#        'Baleares', 'Alicante', 'Murcia', 'Málaga', 'Las Palmas',
#        'Granada', 'Lugo', 'Asturias', 'Pontevedra', 'Córdoba', 'Zaragoza',
#        'León', 'A Coruña', 'Cantabria', 'Toledo', 'Vizcaya', 'Burgos',
#        'Badajoz', 'Lleida', 'Álava', 'Valencia', 'La Rioja', 'Girona',
#        'Jaén', 'Cádiz', 'Ciudad Real', 'Ávila', 'Tarragona', 'Orense',
#        'Huelva', 'Albacete', 'Guipúzcoa', 'Castellón', 'Almería',
#        'Guadalajara', 'Huesca', 'Teruel', 'Valladolid', 'Salamanca',
#        'Cáceres', 'Soria', 'Segovia', 'Cuenca', 'Palencia', 'Zamora',
#        'Ceuta', 'Melilla'], dtype=object)

# %%
df.hist(bins=50, figsize=(10, 6));

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.replace({'Gasolina':1, 'Diésel':0, 'Híbrido enchufable':5, 'Eléctrico':6, 'Gas natural (CNG)':2, 'Híbrido':4, 'Gas licuado (GLP)':3, 'Manual': 0, 'Automático': 1}).corr(numeric_only=True), annot=True, cmap='Blues');

# %% [markdown]
# Se puede observar que el combustible, el año, la potencia, el tipo de cambio y si el vendedor es profesional es lo que más influye. Y que quitando los kilómetros y número de puertas podemos quitar ruido al modelo.

# %%
sns.countplot(x='price',data=df, hue='year', stat='percent')
# Out:
# <Axes: xlabel='price', ylabel='percent'>

# %%
percentiles = df["price"].quantile([0.05, 0.95])
precios = df["price"]
outliers_percentiles = precios[(precios < percentiles[0.05]) | (precios > percentiles[0.95])]

# Visualiza los outliers
plt.hist(precios, color='g')
plt.scatter(outliers_percentiles, np.zeros_like(outliers_percentiles), color='r')
plt.title("Outliers por Percentiles")
plt.show()

# %%
percentiles = df["kms"].quantile([0.05, 0.95])
precios = df["kms"]
outliers_percentiles = precios[(precios < percentiles[0.05]) | (precios > percentiles[0.95])]

# Visualiza los outliers
plt.hist(precios, color='g')
plt.scatter(outliers_percentiles, np.zeros_like(outliers_percentiles), color='r')
plt.title("Outliers por Percentiles KMS")
plt.show()

# %%
percentiles = df["power"].quantile([0.05, 0.95])
precios = df["power"]
outliers_percentiles = precios[(precios < percentiles[0.05]) | (precios > percentiles[0.95])]

# Visualiza los outliers
plt.hist(precios, color='g')
plt.scatter(outliers_percentiles, np.zeros_like(outliers_percentiles), color='r')
plt.title("Outliers por Percentiles KMS")
plt.show()
